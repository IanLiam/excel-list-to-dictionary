# %%
import pandas as pd

# Replace 'your_file.xlsx' with the path to your Excel file
file_path = r'C:\Users\ian.muthengi\Downloads\model.xlsx'

# Replace 'Sheet1' with the name of your sheet and 'ColumnA' with the column name
sheet_name = 'Sheet1'
column_name = 'MODEL'

# Read Excel file into a pandas DataFrame
df = pd.read_excel(file_path, sheet_name=sheet_name)

# Convert the specified column to a dictionary
column_dict = dict(zip(df[column_name], df[column_name].index))

# Print or use the dictionary as needed
print(column_dict)
# Out:
# {'ACE': 0, 'ACECA': 1, 'COBRA': 2, 'CL': 3, 'CSX': 4, 'EL': 5, 'ILX': 6, 'INTEGRA': 1126, 'MDX': 8, 'NSX': 1142, 'RDX': 10, 'RL': 11, 'RLX': 12, 'RSX': 13, 'SLX': 14, 'TL': 15, 'TLX': 16, 'TSX': 17, 'ZDX': 18, 'DIPLOMAT': 2027, 'TRUMPF JUNIOR': 20, '105/115': 21, '145': 1093, '146': 23, '147': 24, '155': 25, '156': 26, '159': 27, '164': 2909, '166': 29, '33': 30, '4C': 31, '6': 2209, '75': 2287, '8C COMPETIZIONE': 34, 'BRERA': 35, 'GIULIA': 36, 'GIULIETTA': 37, 'GT': 2948, 'GTV': 39, 'MITO': 40, 'MONTREAL': 41, 'S.Z./R.Z.': 42, 'SPIDER': 43, 'STELVIO': 44, 'B10': 45, 'B12': 46, 'B3': 47, 'B4': 48, 'B5': 49, 'B6': 50, 'B7': 51, 'B8': 52, 'D10': 53, 'D3': 54, 'D4': 55, 'D5': 56, 'ROADSTER': 2401, 'ROADSTER S': 58, 'ROADSTER V8': 59, 'XD3': 60, 'XD4': 61, 'A110': 62, 'A310': 63, 'A610': 64, 'GTA': 65, 'EAGLE': 66, 'HORNET': 67, '21541 STALKER': 68, '10': 2194, '24': 70, 'SPARTANA': 71, 'ROCSTA': 72, 'TOPIC': 73, 'CYGNET': 74, 'DB AR1': 75, 'DB11': 76, 'DB7': 77, 'DB9': 78, 'DBS': 79, 'D
# ...

# %%
# Out:
# ['ACE',
#  'ACECA',
#  'COBRA',
#  'CL',
#  'CSX',
#  'EL',
#  'ILX',
#  'INTEGRA',
#  'MDX',
#  'NSX',
#  'RDX',
#  'RL',
#  'RLX',
#  'RSX',
#  'SLX',
#  'TL',
#  'TLX',
#  'TSX',
#  'ZDX',
#  'DIPLOMAT',
#  'TRUMPF JUNIOR',
#  '105/115',
#  '145',
#  '146',
#  '147',
#  '155',
#  '156',
#  '159',
#  '164',
#  '166',
#  '33',
#  '4C',
#  '6',
#  '75',
#  '8C COMPETIZIONE',
#  'BRERA',
#  'GIULIA',
#  'GIULIETTA',
#  'GT',
#  'GTV',
#  'MITO',
#  'MONTREAL',
#  'S.Z./R.Z.',
#  'SPIDER',
#  'STELVIO',
#  'B10',
#  'B12',
#  'B3',
#  'B4',
#  'B5',
#  'B6',
#  'B7',
#  'B8',
#  'D10',
#  'D3',
#  'D4',
#  'D5',
#  'ROADSTER',
#  'ROADSTER S',
#  'ROADSTER V8',
#  'XD3',
#  'XD4',
#  'A110',
#  'A310',
#  'A610',
#  'GTA',
#  'EAGLE',
#  'HORNET',
#  '21541 STALKER',
#  '10',
#  '24',
#  'SPARTANA',
#  'ROCSTA',
#  'TOPIC',
#  'CYGNET',
#  'DB AR1',
#  'DB11',
#  'DB7',
#  'DB9',
#  'DBS',
#  'DBX',
#  'LAGONDA',
#  'RAPIDE',
#  'V8 VANTAGE',
#  'V8 ZAGATO',
#  'VANQUISH',
# ...

# %%
 import pandas as pd

def get_distinct_values(file_path, sheet_name, column_name):
    # Read Excel file into a DataFrame
    df = pd.read_excel(file_path, sheet_name=sheet_name)

    # Get distinct values from the specified column
    distinct_values = df[column_name].unique()

    return distinct_values

# Example usage
file_path = r'C:\Users\ian.muthengi\Downloads\like.xlsx'
sheet_name = 'Sheet1'  # Change to your sheet name
column_name = 'MODEL'  # Change to the column from which you want distinct values

df.head()
# Out:
#    MODEL
# 0    ACE
# 1  ACECA
# 2  COBRA
# 3     CL
# 4    CSX

# %%
value_counts = df['MODEL'].value_counts()
value_counts = count_values(file_path, sheet_name, column_name)
print(value_counts)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [85], in <cell line: 2>()
#       1 value_counts = df['MODEL'].value_counts()
# ----> 2 value_counts = count_values(file_path, sheet_name, column_name)
#       3 print(value_counts)
#
# NameError: name 'count_values' is not defined

# %%
df = df.drop_duplicates(subset='MODEL', keep = 'first')

df.head()
df.to_excel('revised.xlsx', index=False)

# %%
df['MODEL'].value_counts()
# Out:
# ACE                 1
# LEAF                1
# JUKE                1
# KICKS               1
# KIX                 1
#                    ..
# POLONEZ             1
# 6500 (LAND KING)    1
# 6500 LAND KING      1
# GN8                 1
# LANDMARK            1
# Name: MODEL, Length: 2706, dtype: int64

# %%
df2 = df['MODEL'].unique()

print(df2)
# Out:
# ['ACE' 'ACECA' 'COBRA' ... 'GRAND TIGER' 'GRANDTIGER' 'LANDMARK']

# %%
df
# Out:
#             MODEL
# 0             ACE
# 1           ACECA
# 2           COBRA
# 3              CL
# 4             CSX
# ...           ...
# 2991         Z100
# 2992         Z300
# 2994  GRAND TIGER
# 2995   GRANDTIGER
# 2996     LANDMARK
#
# [2706 rows x 1 columns]

# %%
df[df2['MODEL']].value_counts()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [79], in <cell line: 1>()
# ----> 1 df[df2['MODEL']].value_counts()
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
df2.to_excel('car model.xlsx')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
# ----> 1 df2.to_excel('car model.xlsx')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'to_excel'
